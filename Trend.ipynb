# %%
import pandas as pd
from IPython.display import display
import os
import shutil
path = os.chdir('C:/Users/jewel.espiritu/OneDrive - AMDATEX LAS PINAS SERVICES INC/Python/py')
sladf = pd.concat(pd.read_excel('./data/WeeklySLA_Data_2022.xlsx', sheet_name=None), ignore_index=True)

# %%
Trendpivot = pd.pivot_table(sladf, index=['Week'], columns=['TTR Result\n(Excluding Pending Time)'], values=['Ticket No'], aggfunc='count')
# Out:
#                                                                                              Ticket No  \
# Operational Status                                                                            On-going
# Service                                            TTR Result\n(Excluding Pending Time) Week
# 3rd Party/ Client Controlled Software, Network ... Beyond TAT                           1         51.0
#                                                                                         2         55.0
#                                                                                         3         48.0
#                                                                                         4         45.0
#                                                                                         5         41.0
# ...                                                                                                ...
# WFH PC setup                                       Within TAT                           19         8.0
#                                                                                         20         5.0
#                                                                                         21        25.0
#                                                                                         22         6.0
#                                                                                         23         8.0
#
#                                                                                                       \
# Operational Status                                                                           Pending
# Service                                            TTR Result\n(Excluding Pending Time) Week
# 3rd Party/ Client Controlled Software, Network ... Beyond TAT                           1       18.0
#                                                                                         2       20.0
#                                                                                         3       15.0
#                                                                                         4        8.0
#                                                                                         5        9.0
# ...                                                                                              ...
# WFH PC setup                                       Within TAT                           19       7.0
#                                                                                         20      20.0
#                                                                                         21      13.0
#                                                                                         22      19.0
#                                                                                         23      13.0
#
#
# Operational Status                                                                           Resolved/ Closed
# Service                                            TTR Result\n(Excluding Pending Time) Week
# 3rd Party/ Client Controlled Software, Network ... Beyond TAT                           1                 1.0
#                                                                                         2                14.0
#                                                                                         3                 6.0
#                                                                                         4                 4.0
#                                                                                         5                21.0
# ...                                                                                                       ...
# WFH PC setup                                       Within TAT                           19               52.0
#                                                                                         20               84.0
#                                                                                         21               56.0
#                                                                                         22               57.0
#                                                                                         23               53.0
#
# [760 rows x 3 columns]

# %%
Trendpivot.columns = Trendpivot.columns.droplevel(0)
Trendpivot.columns.name = None
Trenddf = Trendpivot.reset_index()

# %%
Trenddf["Total Count"] = Trenddf["Beyond TAT"].astype(int) + Trenddf["Within TAT"].astype(int)
Trenddf
# Out:
#     Week  Beyond TAT  Within TAT  Total Count
# 0      1         561        1300         1861
# 1      2         552        1270         1822
# 2      3         537        1004         1541
# 3      4         522        1062         1584
# 4      5         521         918         1439
# 5      6         525        1013         1538
# 6      7         470         983         1453
# 7      8         431        1020         1451
# 8      9         423        1017         1440
# 9     10         421        1058         1479
# 10    11         400        1094         1494
# 11    12         453        1157         1610
# 12    13         479        1158         1637
# 13    14         508        1159         1667
# 14    15         504        1038         1542
# 15    16         726        1838         2564
# 16    17         532        2273         2805
# 17    18         541        1352         1893
# 18    19         671        1719         2390
# 19    20        1100        2739         3839
# 20    21         698        1744         2442
# 21    22         630        1477         2107
# 22    23         617        1521         2138

# %%
FilePath = r'C:\repo\Trend.xlsx'
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(FilePath, engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
Trenddf.to_excel(writer, sheet_name='TREND', index = False)
writer.save()
